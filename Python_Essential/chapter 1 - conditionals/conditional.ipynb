# %% [markdown]
# ### ***Conditional syntax***
# ***

# %%
if False :
    print("hey")
elif  False:
    print("nope")
elif True:
    print("hello")
else:
    print("whaterver")
# Out:
# hello

# %%
# Assignment in conditional

hungry = True
print("im hungry right now" if hungry else "im not hungry")

    # or

hungry = 0
print("im hungry right now" if hungry else "im not hungry")
